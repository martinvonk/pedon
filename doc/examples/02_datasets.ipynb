# %% [markdown]
# **Soil Parameter Datasets**
#
# Generally either the Brooks-Corey or Mualem-van Genuchten soil models are used. Pedon has some built-in datasets with parameter sets that can be used for both soil models.

# %%
import pedon as pe

# %%
# list all soil types for van genuchten
pe.Soil.list_names(pe.Genuchten)
# Out:
# ['HYDRUS_Sand',
#  'HYDRUS_Loamy Sand',
#  'HYDRUS_Sandy Loam',
#  'HYDRUS_Loam',
#  'HYDRUS_Silt',
#  'HYDRUS_Silt Loam',
#  'HYDRUS_Sandy Clay Loam',
#  'HYDRUS_Clay Loam',
#  'HYDRUS_Silty Clay Loam',
#  'HYDRUS_Sandy Clay',
#  'HYDRUS_Silty Clay',
#  'HYDRUS_Clay',
#  'B01',
#  'B02',
#  'B03',
#  'B04',
#  'B05',
#  'B06',
#  'B07',
#  'B08',
#  'B09',
#  'B10',
#  'B11',
#  'B12',
#  'B13',
#  'B14',
#  'B15',
#  'B16',
#  'B17',
#  'B18',
#  'O01',
#  'O02',
#  'O03',
#  'O04',
#  'O05',
#  'O06',
#  'O07',
#  'O08',
#  'O09',
#  'O10',
#  'O11',
#  'O12',
#  'O13',
#  'O14',
#  'O15',
#  'O16',
#  'O17',
#  'O18',
#  'VS2D_Medium Sand',
#  'VS2D_Sandy Loam',
#  'VS2D_Silt Loam',
#  'VS2D_Del Monte Sand',
#  'VS2D_Fresno Medium Sand',
#  'VS2D_Unconsolidated Sand',
#  'VS2D_Sand',
#  'VS2D_Fine Sand',
#  'VS2D_Columbia Sandy Loam',
#  'VS2D_Touchet Silt Loam',
#  'VS2D_Hygiene Sandstone',
#  'VS2D_Adelanto Loam',
#  'VS2D_Limon Silt',
#  'VS2D_Yolo Light Clay']

# %%
# get the HYDRUS sand
soil = pe.Soil(name="HYDRUS_Sand").from_name(sm=pe.Genuchten)
soil
# Out:
# Soil(name='HYDRUS_Sand', type='Sand', model=Genuchten(k_s=712.8, theta_r=0.045, theta_s=0.43, alpha=0.145, n=2.68, l=0.5), sample=None, source='HYDRUS', description=nan)

# %% [markdown]
# Note that we now have a different class; the soil class. This class has some other attributes such as the name. If the name is in the dataset (`pe.Soil.list_names(pe.Genuchten)`), the `from_name()` can retrieve the soil model. Note that we have to parse the soil model `sm` as an attribute since some soil models are available both as a Genuchten and Brooks dataset.

# %%
# get from the Staring series
pe.Soil("O18").from_staring(year="2001")
# Out:
# Soil(name='O18', type='Peat', model=Genuchten(k_s=34.45, theta_r=0.01, theta_s=0.57, alpha=0.0138, n=1.323, l=-1.204), sample=SoilSample(sand_p=None, silt_p=0.0, clay_p=0.0, rho=1.1, th33=None, th1500=None, om_p=22.5, m50=nan), source='Staring', description='moerige tussenlaag')

# %%
# get for both genuchten and brooks
ls_gen = pe.Soil("VS2D_Limon Silt").from_name(sm=pe.Genuchten)
ls_bro = pe.Soil("VS2D_Limon Silt").from_name(sm=pe.Brooks)

ax = ls_gen.model.plot()
ls_bro.model.plot(ax=ax)
ax.legend()
ax.set_title(ls_gen.name)
# Out:
# Text(0.5, 1.0, 'VS2D_Limon Silt')
