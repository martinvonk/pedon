# %%
import pedon as pe

# %% [markdown]
# From Bashir, R., Sharma, J., & Stefaniak, H. (2016). Effect of hysteresis of soil-water characteristic curves on infiltration under different climatic conditions. Canadian Geotechnical Journal, 53(2), 273–284. https://doi.org/10.1139/cgj-2015-0004
#
# ParameterSoil LoamSoil SiltySand SiltyLoam
#
# theta_r 0.21 0.07 0.03
#
# theta_s 0.52 0.38 0.4
#
# n 1.704 2.02 1.228
#
# Ks (mm/day) 19.15 259.2 1373
#
# alpha_d (1/mm) 0.0015 0.002 0.0091
#
# alpha_w (1/mm) 0.008 0.003 0.0503

# %%
gen = pe.GenuchtenKool(
    k_s=1.915, theta_r=0.21, theta_s=0.52, n=1.704, alpha=0.0015, xi=1.5
)
gen.plot()
# Out:
# <Axes: >
